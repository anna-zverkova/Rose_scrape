# %%
# import the library we use to open URLs
import urllib.request

# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup

# import the Pandas library so we can review and manipulate scraped data in dataframes
import pandas as pd

# %%
# specify which URL/web page we are going to be scraping
url = "https://en.wikipedia.org/wiki/World_Federation_of_Rose_Societies"

# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)

# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
all_tables=soup.find_all("table")
all_tables
# Out:
# [<table class="sortable wikitable">
#  <tbody><tr>
#  <th class="sortable">Society country
#  </th>
#  <th class="sortable">Society name
#  </th>
#  <th class="sortable">Year established
#  </th></tr>
#  <tr>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/> </span><a href="/wiki/Argentina" title="Argentina">Argentina</a>
#  </td>
#  <td>Rose Society of Argentina
#  </td>
#  <td>1951<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
#  </td></tr>
#  <tr>
# ...

# %%
# Selecting right table (the one we want)
right_table=soup.find('table', class_='sortable wikitable')
right_table
# Out:
# <table class="sortable wikitable">
# <tbody><tr>
# <th class="sortable">Society country
# </th>
# <th class="sortable">Society name
# </th>
# <th class="sortable">Year established
# </th></tr>
# <tr>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/> </span><a href="/wiki/Argentina" title="Argentina">Argentina</a>
# </td>
# <td>Rose Society of Argentina
# </td>
# <td>1951<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </td></tr>
# <tr>
# ...

# %%
# Let's import this HTML table in a DataFrame.
df = pd.read_html(str(right_table))[0]
df
# Out:
#       Society country                                       Society name  \
# 0           Argentina                          Rose Society of Argentina
# 1           Australia                 National Rose Society of Australia
# 2             Austria  Österreichische Rosenfreunde in derÖsterreichi...
# 3             Belgium  Société Royale Nationale 'Les Amis de la Rose'...
# 4             Bermuda                               Bermuda Rose Society
# 5              Canada                              Canadian Rose Society
# 6               Chile                      Asociación Chilena de la Rosa
# 7   Republic of China                               Chinese Rose Society
# 8      Czech Republic                                    Czech Rosa Club
# 9             Denmark  Det Danske Rosenselskab/The Danish Rose Societ...
# 10            Finland  Suomen Ruususeura r.y. - Finska Rosensällskape...
# 11             France                        Société Française des Roses
# ...
